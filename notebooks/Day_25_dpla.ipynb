# %% [markdown]
# launch of dp.la API v2:
# https://cyber.law.harvard.edu/lists/arc/dpla-tech/2013-04/msg00004.html
#
# Need a key, which you can get, using [incantation from Tom Morris](https://cyber.law.harvard.edu/lists/arc/dpla-tech/2013-04/msg00007.html):
#
#     curl -v -XPOST http://api.dp.la/v2/api_key/you@your_email.com
#
# As Tom wrote:  "If you use Gmail, check your spam folder. The key is sent immediately."

# %% [markdown]
# Europeana API: http://pro.europeana.eu/api

# %%
# Goal:  feed a bunch of search terms to try to get at some collections

# API doc: https://github.com/dpla/platform/
# test data sources: http://dp.la/wiki/Platform_test_data_sources

import requests
import json
import urllib
from itertools import islice

from CREDENTIALS import DPLA_KEY

# http://api.dp.la/v2/items?api_key=YOUR_API_KEY

# Retrieve an item by ID
# http://api.dp.la/v2/items/a4e2346032cae75b0832abe064c14bcb

# Retrieve multiple items by ID
# http://api.dp.la/v1/items/a4e2346032cae75b0832abe0644e9b26,a4e2346032cae75b0832abe064c14bcb


def dpla_query(**kw_input):
    
    kwargs = {"page_size": 20, "page": 1, "sort_order":"asc", "api_key":DPLA_KEY}
    
    # fudgy -- allow an extra parameter to allow for ones that can fit kw_input -- e.g., spatial.coordinates
    extras = kw_input.pop('extras',{})
    kw_input.update(extras)
    
    kwargs.update(kw_input)
    kwargs = dict([(k,v) for (k,v) in kwargs.items() if v is not None])
    
    # asc vs desc
    
    # available text search fields
    text_search_fields = ("title", "description", "dplaContributor", "creator", "type", "publisher", "format", "rights", "contributor", "spatial")
    expected_doc_fields = ['title','description', 'creator', 'type', 'publisher', 'format', 'rights', 'contributor', 'created', 'spatial', 'temporal', 'source']
    
    # temporal fields
    # http://api.dp.la/v1/items?temporal.after=1963-11-01&temporal.before=1963-11-30
    
    # location available...not implemented here
    more_items = True
    
   # content["count"], content["start"], content["limit"]
    
    while more_items:
        
        r = requests.get("http://api.dp.la/v2/items?" + urllib.urlencode(kwargs))
        content = json.loads(r.content)
        
        if len(content.get("docs", [])):
            for doc in content["docs"]:
                yield (doc, content["count"])
            if kwargs['sort_order'] == 'desc':
                kwargs['page'] -= 1
            else:
                kwargs['page'] += 1
        else:
            more_items = False


# search terms to feed in 

SEARCH_TERMS = ["Bach", "tree", "horse", "cow", "Gore"]

# collections 
collections = set()

for term in islice(SEARCH_TERMS,1):
    results = list(islice(dpla_query(q=term),100)) 
            
    for (i, (doc, count)) in enumerate(results):
        collections.add(doc.get('isPartOf', {'title':None}).get('title'))
    
print len(collections)

# for each collection let's figure out the number of items in the collection

from IPython.display import HTML
from jinja2 import Template

num_items = []

for (i, collection) in enumerate(sorted(collections)):
    if collection is not None:
        size_collection = list(islice(dpla_query(isPartOf=collection),1))[0][1] if collection is not None else 0
        url = "http://api.dp.la/v1/items?" + urllib.urlencode({'isPartOf': collection})
        num_items.append((collection, size_collection, url))
    else:
        num_items.append((None, 0, ""))
    
TABLE_TEMPLATE = """<table>
 <tr>
   <th>Collection</th>
   <th>Number of items</th>
   <th>API</th>
 </tr>
 {% for num_item in num_items %}
 <tr>
  <td>{{num_item.0}}</td>
  <td>{{num_item.1}}</td>
  <td><a href="{{num_item.2}}">{{num_item.2}}</a></td>
{% endfor %}
 </tr>
"""
    
template = Template(TABLE_TEMPLATE)
HTML(template.render(num_items=num_items))
# Out:
# 1
# <table>
#  <tr>
#    <th>Collection</th>
#    <th>Number of items</th>
#    <th>API</th>
#  </tr>
#
#  <tr>
#   <td>None</td>
#   <td>0</td>
#   <td><a href=""></a></td>
#
#  </tr>

# %%
r = dpla_query(q='Bach')

# %%
r0 = list(islice(r,10))

# %%
r0
# Out:
# [({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/591caf17cd9be263b4c0d12a22db87db',
#    u'_id': u'ia--conspectusofwork00bach',
#    u'_rev': u'1-ea370ca00cfc32ace165d037eb4f50f2',
#    u'dataProvider': u'Wellesley College Library',
#    u'hasView': {u'@id': u'http://www.archive.org/download/conspectusofwork00bach/conspectusofwork00bach.pdf',
#     u'format': u'application/pdf',
#     u'rights': None},
#    u'id': u'591caf17cd9be263b4c0d12a22db87db',
#    u'ingestDate': u'2013-04-12T18:27:20.511426',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://www.archive.org/details/conspectusofwork00bach',
#    u'originalRecord': {u'_id': u'conspectusofwork00bach',
#     u'files': {u'dc': u'conspectusofwork00bach_dc.xml',
#      u'gif': u'conspectusofwork00bach.gif',
#      u'marc': u'conspectusofwork00bach_marc.xml',
#      u'meta': u'conspectusofwork00bach_meta.xml',
#      u'pdf': u'conspectusofwork00bach.pdf',
#      u'shown_at': u'http://archive.org/details/conspectusofwork00bach'},
#     u'metadata': {u'addeddate': u'2011-02-11 15:23:46',
#      u'bookplateleaf': u'0008',
#      u'call_number': u'b1510039x',
#      u'camera': u'Canon 5D',
#      u'collection': [u'Wellesley_College_Library', u'blc', u'americana'],
#      u'contributor': u'Wellesley College Library',
#      u'creator': [u'Bach, Johann Sebastian, 1685-1750',
#       u'Rumberger, Marian S. (Marian Stewart)'],
#      u'curation': u'[curator]andy-seronick@archive.org[/curator][date]20110222165417[/date][state]approved[/state][comment]199[/comment]',
#      u'date': u'1948',
#      u'description': u'Lithoprint copy of typescript manuscript',
#      u'foldoutcount': u'0',
#      u'identifier': u'conspectusofwork00bach',
#      u'identifier-access': u'http://www.archive.org/details/conspectusofwork00bach',
#      u'identifier-ark': u'ark:/13960/t20c5sd3c',
#      u'imagecount': u'70',
#      u'language': u'eng',
#      u'mediatype': u'texts',
#      u'ocr': u'ABBYY FineReader 8.0',
#      u'operator': u'scanner-elena-ricci@archive.org',
#      u'page-progression': u'lr',
#      u'ppi': u'400',
#      u'publicdate': u'2011-02-11 15:23:50',
#      u'publisher': u'Ann Arbor : J.W. Edwards',
#      u'repub_state': u'4',
#      u'scandate': u'20110218170058',
#      u'scanfee': u'15',
#      u'scanner': u'scribe7.boston.archive.org',
#      u'scanningcenter': u'boston',
#      u'sponsor': u'Boston Library Consortium Member Libraries',
#      u'sponsordate': u'20110228',
#      u'subject': u'Bach, Johann Sebastian, 1685-1750',
#      u'title': u'A conspectus of the works of Johann Sebastian Bach : compiled for the Bach-Gesellschaft edition',
#      u'updatedate': u'2011-02-11 15:23:44',
#      u'updater': u'LisaEgge',
#      u'uploader': u'lisae@archive.org'},
#     u'record': {u'controlfield': [{u'#text': u'2050127', u'tag': u'001'},
#       {u'#text': u'19880318103729.0', u'tag': u'005'},
#       {u'#text': u'760315s1948    miu      i    000 0 eng d', u'tag': u'008'}],
#      u'datafield': [{u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'KLG', u'code': u'a'},
#         {u'#text': u'KLG', u'code': u'c'},
#         {u'#text': u'm.c.', u'code': u'd'},
#         {u'#text': u'WEL', u'code': u'd'}],
#        u'tag': u'040'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'WELM', u'code': u'a'},
#        u'tag': u'049'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'M3', u'code': u'a'},
#         {u'#text': u'.B11 Index', u'code': u'b'}],
#        u'tag': u'090'},
#       {u'ind1': u'1',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Bach, Johann Sebastian,', u'code': u'a'},
#         {u'#text': u'1685-1750.', u'code': u'd'}],
#        u'tag': u'100'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Works.', u'code': u'a'},
#         {u'#text': u'Index.', u'code': u'p'}],
#        u'tag': u'240'},
#       {u'ind1': u'1',
#        u'ind2': u'2',
#        u'subfield': [{u'#text': u'A conspectus of the works of Johann Sebastian Bach :',
#          u'code': u'a'},
#         {u'#text': u'compiled for the Bach-Gesellschaft edition /',
#          u'code': u'b'},
#         {u'#text': u'by Marion S. Rumberger.', u'code': u'c'}],
#        u'tag': u'245'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Ann Arbor :', u'code': u'a'},
#         {u'#text': u'J.W. Edwards,', u'code': u'b'},
#         {u'#text': u'1948.', u'code': u'c'}],
#        u'tag': u'260'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'ix, 48 p. ;', u'code': u'a'},
#         {u'#text': u'22 cm.', u'code': u'c'}],
#        u'tag': u'300'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'Lithoprint copy of typescript manuscript.',
#         u'code': u'a'},
#        u'tag': u'500'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach, Johann Sebastian,', u'code': u'a'},
#         {u'#text': u'1685-1750', u'code': u'd'},
#         {u'#text': u'Dictionaries.', u'code': u'v'}],
#        u'tag': u'600'},
#       {u'ind1': u'1',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Rumberger, Marian S.', u'code': u'a'},
#         {u'#text': u'(Marian Stewart)', u'code': u'q'}],
#        u'tag': u'700'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'.b1510039x', u'code': u'a'},
#        u'tag': u'907'}],
#      u'leader': u'00731nam a2200205Ii 450 ',
#      u'xmlns': u'http://www.loc.gov/MARC21/slim'}},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/internet_archive',
#     u'name': u'Internet Archive'},
#    u'score': 2.0988917,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/190b7921c442008cb8e538f61cdab6cb',
#      u'id': u'190b7921c442008cb8e538f61cdab6cb',
#      u'title': u'Boston Library Consortium Member Libraries'},
#     u'creator': [u'Bach, Johann Sebastian, 1685-1750',
#      u'Rumberger, Marian S. (Marian Stewart)'],
#     u'date': {u'begin': u'1948', u'displayDate': u'1948', u'end': u'1948'},
#     u'description': u'Lithoprint copy of typescript manuscript',
#     u'extent': u'22 cm.',
#     u'identifier': [u'conspectusofwork00bach', u'b1510039x'],
#     u'language': [{u'iso639_3': u'eng', u'name': u'English'}],
#     u'publisher': u'Ann Arbor : J.W. Edwards',
#     u'subject': [{u'name': u'Bach, Johann Sebastian, 1685-1750'}],
#     u'title': u'A conspectus of the works of Johann Sebastian Bach : compiled for the Bach-Gesellschaft edition',
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/1bde1202855b8a46b7061051fb039109',
#    u'_id': u'digital-commonwealth--http://digitalcommonwealth.org/items/show/62697',
#    u'_rev': u'1-4009773e0b8ed9aa954dc68f55f87f69',
#    u'dataProvider': u'Digital Commonwealth',
#    u'id': u'1bde1202855b8a46b7061051fb039109',
#    u'ingestDate': u'2013-04-12T08:11:38.078294',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://openvault.wgbh.org/catalog/vietnam-41aa2f-bach-dang-estuary  ',
#    u'originalRecord': {u'datestamp': u'2013-02-24T18:48:02Z',
#     u'description': u'Scenes of Bach Dang estuary where Chinese invasions have been repulsed.  ',
#     u'format': u'video  ',
#     u'handle': [u'http://openvault.wgbh.org/catalog/vietnam-41aa2f-bach-dang-estuary  ',
#      u'http://digitalcommonwealth.org/items/show/62697'],
#     u'id': u'oai:digitalcommonwealth.org:62697',
#     u'label': u'Bach Dang Estuary  ',
#     u'setSpec': u'215',
#     u'subject': u'Estuaries--Vietnam Bicycles Rivers Vietnam Boats and boating  ',
#     u'title': u'Bach Dang Estuary  '},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/digital-commonwealth',
#     u'name': u'Digital Commonwealth'},
#    u'score': 2.069715,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/285ca7b8845da5e6316e6558fac491b4',
#      u'id': u'285ca7b8845da5e6316e6558fac491b4',
#      u'title': u'Buckland Collection'},
#     u'description': u'Scenes of Bach Dang estuary where Chinese invasions have been repulsed.',
#     u'format': u'Video',
#     u'subject': [{u'name': u'Estuaries--Vietnam Bicycles Rivers Vietnam Boats and boating'}],
#     u'title': u'Bach Dang Estuary'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/e2fef6159558dab22e86a7424ccb45c3',
#    u'_id': u'ia--bachfamilyseveng00geir',
#    u'_rev': u'1-e6b2599091e70e456236d23134d73ebe',
#    u'dataProvider': u'Wellesley College Library',
#    u'hasView': {u'@id': u'http://www.archive.org/download/bachfamilyseveng00geir/bachfamilyseveng00geir.pdf',
#     u'format': u'application/pdf',
#     u'rights': None},
#    u'id': u'e2fef6159558dab22e86a7424ccb45c3',
#    u'ingestDate': u'2013-04-12T16:47:47.172236',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://www.archive.org/details/bachfamilyseveng00geir',
#    u'originalRecord': {u'_id': u'bachfamilyseveng00geir',
#     u'files': {u'dc': u'bachfamilyseveng00geir_dc.xml',
#      u'gif': u'bachfamilyseveng00geir.gif',
#      u'marc': u'bachfamilyseveng00geir_marc.xml',
#      u'meta': u'bachfamilyseveng00geir_meta.xml',
#      u'pdf': u'bachfamilyseveng00geir.pdf',
#      u'shown_at': u'http://archive.org/details/bachfamilyseveng00geir'},
#     u'metadata': {u'addeddate': u'2011-07-27 18:27:07',
#      u'bookplateleaf': u'0003',
#      u'call_number': u'b1401206',
#      u'camera': u'Canon 5D',
#      u'collection': [u'Wellesley_College_Library', u'blc', u'americana'],
#      u'contributor': u'Wellesley College Library',
#      u'creator': u'Geiringer, Karl, 1899-1989',
#      u'curation': u'[curator]andy-seronick@archive.org[/curator][date]20110802145212[/date][state]approved[/state]',
#      u'date': u'1954',
#      u'description': u'Bibliography: p. 490-495. "Index of compositions by members of the Bach family": p. 506-514',
#      u'foldoutcount': u'0',
#      u'identifier': u'bachfamilyseveng00geir',
#      u'identifier-access': u'http://www.archive.org/details/bachfamilyseveng00geir',
#      u'identifier-ark': u'ark:/13960/t4vh6g612',
#      u'imagecount': u'576',
#      u'language': u'eng',
#      u'mediatype': u'texts',
#      u'ocr': u'ABBYY FineReader 8.0',
#      u'operator': u'scanner-kelly-powers@archive.org',
#      u'page-progression': u'lr',
#      u'ppi': u'400',
#      u'publicdate': u'2011-07-27 18:27:13',
#      u'publisher': u'New York, Oxford University Press',
#      u'repub_seconds': u'1549',
#      u'repub_state': u'4',
#      u'scandate': u'20110728152743',
#      u'scanfee': u'100',
#      u'scanner': u'scribe8.boston.archive.org',
#      u'scanningcenter': u'boston',
#      u'sponsor': u'Boston Library Consortium Member Libraries',
#      u'sponsordate': u'20110731',
#      u'subject': [u'Bach family', u'Bach, Johann Sebastian, 1685-1750'],
#      u'title': u'The Bach family; seven generations of creative genius',
#      u'updatedate': u'2011-07-27 18:27:05',
#      u'updater': u'TimB-foldout-op',
#      u'uploader': u'tim-bigelow@archive.org'},
#     u'record': {u'controlfield': [{u'#text': u'853366', u'tag': u'001'},
#       {u'#text': u'19860811131323.0', u'tag': u'005'},
#       {u'#text': u'730522s1954    nyuabcf  b    000 0ceng  ', u'tag': u'008'}],
#      u'datafield': [{u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'54013129', u'code': u'a'},
#        u'tag': u'010'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'DLC', u'code': u'a'},
#         {u'#text': u'DLC', u'code': u'c'},
#         {u'#text': u'm.c.', u'code': u'd'},
#         {u'#text': u'WEL', u'code': u'd'}],
#        u'tag': u'040'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'WELM', u'code': u'a'},
#         {u'#text': u'1-2', u'code': u'c'}],
#        u'tag': u'049'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'ML410.B1', u'code': u'a'},
#         {u'#text': u'G397', u'code': u'b'}],
#        u'tag': u'050'},
#       {u'ind1': u'1',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Geiringer, Karl,', u'code': u'a'},
#         {u'#text': u'1899-1989.', u'code': u'd'}],
#        u'tag': u'100'},
#       {u'ind1': u'1',
#        u'ind2': u'4',
#        u'subfield': [{u'#text': u'The Bach family;', u'code': u'a'},
#         {u'#text': u'seven generations of creative genius', u'code': u'b'},
#         {u'#text': u'[by] Karl Geiringer in collaboration with Irene Geiringer.',
#          u'code': u'c'}],
#        u'tag': u'245'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'New York,', u'code': u'a'},
#         {u'#text': u'Oxford University Press,', u'code': u'b'},
#         {u'#text': u'1954.', u'code': u'c'}],
#        u'tag': u'260'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'xiv, 514 p.', u'code': u'a'},
#         {u'#text': u'illus., 26 plates (incl. ports., facsims.) map, music.',
#          u'code': u'b'},
#         {u'#text': u'25 cm.', u'code': u'c'}],
#        u'tag': u'300'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'Bibliography: p. 490-495. "Index of compositions by members of the Bach family": p. 506-514.',
#         u'code': u'a'},
#        u'tag': u'504'},
#       {u'ind1': u'3',
#        u'ind2': u'0',
#        u'subfield': {u'#text': u'Bach family.', u'code': u'a'},
#        u'tag': u'600'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach, Johann Sebastian,', u'code': u'a'},
#         {u'#text': u'1685-1750.', u'code': u'd'}],
#        u'tag': u'600'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'.b14012066', u'code': u'a'},
#        u'tag': u'907'}],
#      u'leader': u'00789cam a22002051  450 ',
#      u'xmlns': u'http://www.loc.gov/MARC21/slim'}},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/internet_archive',
#     u'name': u'Internet Archive'},
#    u'score': 2.0472765,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/190b7921c442008cb8e538f61cdab6cb',
#      u'id': u'190b7921c442008cb8e538f61cdab6cb',
#      u'title': u'Boston Library Consortium Member Libraries'},
#     u'creator': u'Geiringer, Karl, 1899-1989',
#     u'date': {u'begin': u'1954', u'displayDate': u'1954', u'end': u'1954'},
#     u'description': u'Bibliography: p. 490-495. "Index of compositions by members of the Bach family": p. 506-514',
#     u'extent': u'25 cm.',
#     u'identifier': [u'bachfamilyseveng00geir', u'b1401206'],
#     u'language': [{u'iso639_3': u'eng', u'name': u'English'}],
#     u'publisher': u'New York, Oxford University Press',
#     u'subject': [{u'name': u'Bach family'},
#      {u'name': u'Bach, Johann Sebastian, 1685-1750'}],
#     u'title': u'The Bach family; seven generations of creative genius',
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/a41e3cb3f02540ea03cced74942128cf',
#    u'_id': u'ia--friedemannbachei01brac',
#    u'_rev': u'1-922ef1cb341a1184315a6147d2da95bb',
#    u'dataProvider': u'University of Connecticut Libraries',
#    u'hasView': {u'@id': u'http://www.archive.org/download/friedemannbachei01brac/friedemannbachei01brac_bw.pdf',
#     u'format': u'application/pdf',
#     u'rights': u'NOT_IN_COPYRIGHT'},
#    u'id': u'a41e3cb3f02540ea03cced74942128cf',
#    u'ingestDate': u'2013-04-12T18:09:37.935410',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://www.archive.org/details/friedemannbachei01brac',
#    u'originalRecord': {u'_id': u'friedemannbachei01brac',
#     u'files': {u'dc': u'friedemannbachei01brac_dc.xml',
#      u'gif': u'friedemannbachei01brac.gif',
#      u'marc': u'friedemannbachei01brac_marc.xml',
#      u'meta': u'friedemannbachei01brac_meta.xml',
#      u'pdf': u'friedemannbachei01brac_bw.pdf',
#      u'shown_at': u'http://archive.org/details/friedemannbachei01brac'},
#     u'metadata': {u'addeddate': u'2008-08-25 15:22:26',
#      u'camera': u'Canon 5D',
#      u'collection': [u'uconn_libraries', u'blc', u'americana'],
#      u'contributor': u'University of Connecticut Libraries',
#      u'creator': u'Brachvogel, Albert Emil, 1824-1878',
#      u'curation': u'[curator]julie@archive.org[/curator][date]20080909210201[/date][state]approved[/state]',
#      u'date': u'1858',
#      u'foldoutcount': u'0',
#      u'identifier': u'friedemannbachei01brac',
#      u'identifier-access': u'http://www.archive.org/details/friedemannbachei01brac',
#      u'identifier-ark': u'ark:/13960/t74t6sj9j',
#      u'imagecount': u'390',
#      u'language': u'ger',
#      u'lcamid': None,
#      u'mediatype': u'texts',
#      u'missingpages': None,
#      u'operator': u'scanner-matt-donnelly@archive.org',
#      u'possible-copyright-status': u'NOT_IN_COPYRIGHT',
#      u'ppi': u'500',
#      u'publicdate': u'2008-08-25 15:22:30',
#      u'publisher': u'Berlin : O. Janke',
#      u'rcamid': None,
#      u'repub_state': u'4',
#      u'scandate': u'20080826193244',
#      u'scanfactors': u'3',
#      u'scanner': u'scribe6.boston.archive.org',
#      u'scanningcenter': u'boston',
#      u'sponsor': u'University of Connecticut Libraries',
#      u'sponsordate': u'20080831',
#      u'subject': [u'Bach, Wilhelm Friedemann, 1710-1784', u'Bach family'],
#      u'title': u'Friedemann Bach : ein Roman',
#      u'updatedate': u'2008-08-25 15:22:24',
#      u'updater': u'David Burke',
#      u'uploader': u'davidburke@archive.org',
#      u'volume': u'1'},
#     u'record': {u'controlfield': [{u'#text': u'221589', u'tag': u'001'},
#       {u'#text': u'19990630230741.0', u'tag': u'005'},
#       {u'#text': u'790111s1858    gw            000 1 ger d', u'tag': u'008'}],
#      u'datafield': [{u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'(OCoLC)04539982', u'code': u'a'},
#        u'tag': u'035'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'AAY3200ST', u'code': u'9'},
#        u'tag': u'035'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'UCW', u'code': u'a'},
#         {u'#text': u'UCW', u'code': u'c'}],
#        u'tag': u'040'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'UCWW', u'code': u'a'},
#        u'tag': u'049'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'PT1824.B4', u'code': u'a'},
#         {u'#text': u'F7', u'code': u'b'},
#         {u'#text': u'UCWW', u'code': u'm'}],
#        u'tag': u'090'},
#       {u'ind1': u'1',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Brachvogel, Albert Emil,', u'code': u'a'},
#         {u'#text': u'1824-1878.', u'code': u'd'}],
#        u'tag': u'100'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Friedemann Bach :', u'code': u'a'},
#         {u'#text': u'ein Roman /', u'code': u'b'},
#         {u'#text': u'von A. E. Brachvogel.', u'code': u'c'}],
#        u'tag': u'245'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Berlin :', u'code': u'a'},
#         {u'#text': u'O. Janke,', u'code': u'b'},
#         {u'#text': u'1858.', u'code': u'c'}],
#        u'tag': u'260'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'2 v. ;', u'code': u'a'},
#         {u'#text': u'18 cm.', u'code': u'c'}],
#        u'tag': u'300'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach, Wilhelm Friedemann,', u'code': u'a'},
#         {u'#text': u'1710-1784', u'code': u'd'},
#         {u'#text': u'In literature.', u'code': u'x'}],
#        u'tag': u'600'},
#       {u'ind1': u'3',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach family', u'code': u'a'},
#         {u'#text': u'In literature.', u'code': u'x'}],
#        u'tag': u'600'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'IN  11 JAN 79', u'code': u'a'},
#        u'tag': u'940'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'HLD pd', u'code': u'a'},
#        u'tag': u'948'}],
#      u'leader': u'00630nam a2200217 i 4500',
#      u'xmlns': u'http://www.loc.gov/MARC21/slim'}},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/internet_archive',
#     u'name': u'Internet Archive'},
#    u'score': 1.8146741,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/190b7921c442008cb8e538f61cdab6cb',
#      u'id': u'190b7921c442008cb8e538f61cdab6cb',
#      u'title': u'University of Connecticut Libraries'},
#     u'creator': u'Brachvogel, Albert Emil, 1824-1878',
#     u'date': {u'begin': u'1858', u'displayDate': u'1858', u'end': u'1858'},
#     u'extent': u'18 cm.',
#     u'identifier': u'friedemannbachei01brac',
#     u'language': [{u'iso639_3': u'deu', u'name': u'German'}],
#     u'publisher': u'Berlin : O. Janke',
#     u'rights': u'NOT_IN_COPYRIGHT',
#     u'subject': [{u'name': u'Bach, Wilhelm Friedemann, 1710-1784'},
#      {u'name': u'Bach family'}],
#     u'title': u'Friedemann Bach : ein Roman, 1',
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:end', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/13a3250cdfd268d5d90f333b45bcde47',
#    u'_id': u'mwdl--digcoll_byu_12Bach2/2822',
#    u'_rev': u'1-d0ba9a3a0837243dad2740068c4ec72b',
#    u'dataProvider': u'Brigham Young University - Harold B. Lee Library',
#    u'id': u'13a3250cdfd268d5d90f333b45bcde47',
#    u'ingestDate': u'2013-04-12T21:34:19.294384',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://thoth.library.utah.edu:1701/primo_library/libweb/action/dlDisplay.do?vid=MWDL&afterPDS=true&docId=digcoll_byu_12Bach2/2822',
#    u'object': u'http://contentdm.lib.byu.edu/utils/getthumbnail/collection/Bach2/id/2822',
#    u'originalRecord': {u'GETIT': {u'GetIt1': u'http://archives.state.ut.us/cgi-bin/index-oai.cgi?KEYPATH=IDX208420190387',
#      u'GetIt2': u'http://sfx7.exlibrisgroup.com/uutah?ctx_ver=Z39.88-2004&ctx_enc=info:ofi/enc:UTF-8&ctx_tim=2013-04-12T19%3A31%3A44IST&url_ver=Z39.88-2004&url_ctx_fmt=infofi/fmt:kev:mtx:ctx&rfr_id=info:sid/primo.exlibrisgroup.com:primo3-Journal-digcoll_usa_24&rft_val_fmt=info:ofi/fmt:kev:mtx:&rft.genre=&rft.atitle=&rft.jtitle=&rft.btitle=&rft.aulast=&rft.auinit=&rft.auinit1=&rft.auinitm=&rft.ausuffix=&rft.au=&rft.aucorp=&rft.volume=&rft.issue=&rft.part=&rft.quarter=&rft.ssn=&rft.spage=&rft.epage=&rft.pages=&rft.artnum=&rft.issn=&rft.eissn=&rft.isbn=&rft.sici=&rft.coden=&rft_id=info:doi/&rft.object_id=&rft.eisbn=&rft_dat=<digcoll_usa_24>190387</digcoll_usa_24>&rft_id=info:oai/',
#      u'deliveryCategory': u'Online Resource'},
#     u'ID': u'1899071',
#     u'LINKS': {u'linktorsrc': u'http://contentdm.lib.byu.edu/u?/Bach2,2822',
#      u'thumbnail': u'http://contentdm.lib.byu.edu/utils/getthumbnail/collection/Bach2/id/2822'},
#     u'NO': u'225997',
#     u'PrimoNMBib': {u'record': {u'addata': {u'date': u'1992',
#        u'pub': [u'Sunburst Pub.', u'Brigham Young University']},
#       u'control': {u'addsrcrecordid': u'byu-12-102-1077',
#        u'originalsourceid': u'2822',
#        u'recordid': u'digcoll_byu_12Bach2/2822',
#        u'sourcedbandrecordid': u'Bach2',
#        u'sourceformat': u'Digital Entity',
#        u'sourceid': u'digcoll_byu_12',
#        u'sourcerecordid': u'Bach2/2822',
#        u'sourcesystem': u'Other'},
#       u'delivery': {u'delcategory': u'Online Resource',
#        u'institution': u'MWDL'},
#       u'display': {u'creationdate': u'1992',
#        u'creator': u'Bach, Marcus, 1906-',
#        u'description': [u'Electronic reproduction;',
#         u'158 p. : ill. ; 22 cm.'],
#        u'format': u'text/pdf',
#        u'identifier': [u'who_stole_my_utopia_030603_132855',
#         u'http://contentdm.lib.byu.edu/u?/Bach2,2822'],
#        u'language': u'eng;eng;eng',
#        u'lds01': u'Brigham Young University, Harold B. Lee Library',
#        u'lds02': u'Brigham Young University CONTENTdm Server Repository',
#        u'lds03': u'Brigham Young University - Harold B. Lee Library',
#        u'lds04': u'Marcus Bach',
#        u'lds12': u'Brigham Young University',
#        u'lds17': u'text',
#        u'lds18': u'text',
#        u'publisher': u'Sunburst Pub.; Brigham Young University',
#        u'relation': u'Is part of: Marcus Bach Collection',
#        u'rights': u'http://www.lib.byu.edu/generic_copyright.html; By permission of the Dr. Marcus and Lorena Bach Endowed Fund; Public',
#        u'subject': u'Bach, Marcus, 1906- --Childhood and youth;; Books;',
#        u'title': u'Who Stole my Utopia',
#        u'type': u'Text'},
#       u'facets': {u'collection': u'Digital Collections',
#        u'creationdate': [u'1992', u'2005-06'],
#        u'creatorcontrib': u'Bach, Marcus, 1906-',
#        u'format': u'text/pdf',
#        u'frbrgroupid': u'110903099',
#        u'frbrtype': u'6',
#        u'genre': u'unknown',
#        u'language': [u'eng', u'eng', u'eng'],
#        u'lfc01': u'Marcus Bach',
#        u'lfc02': u'Brigham Young University - Harold B. Lee Library',
#        u'lfc03': u'Brigham Young University, Harold B. Lee Library',
#        u'lfc04': u'Brigham Young University CONTENTdm Server Repository',
#        u'prefilter': u'text',
#        u'rsrctype': u'text',
#        u'topic': [u'Bach, Marcus, 1906- --Childhood and youth', u'Books'],
#        u'toplevel': u'online_resources'},
#       u'links': {u'linktorsrc': u'$$Tdigcoll_byu_12_linktores$$DOpen resource in a new window',
#        u'thumbnail': u'$$Tdigcoll_byu_12_linktothumb$$DSee Thumbnail'},
#       u'ranking': {u'booster1': u'1', u'booster2': u'1'},
#       u'search': {u'addsrcrecordid': u'byu-12-102-1077',
#        u'addtitle': u'Is part of: Marcus Bach Collection',
#        u'creationdate': [u'1992', u'2005-06'],
#        u'creatorcontrib': u'Bach, Marcus, 1906-',
#        u'description': [u'Electronic reproduction;',
#         u'158 p. : ill. ; 22 cm.'],
#        u'lsr01': u'byu',
#        u'lsr02': u'12',
#        u'lsr03': u'102',
#        u'lsr04': u'1077',
#        u'lsr09': u'Brigham Young University, Harold B. Lee Library',
#        u'lsr10': u'Brigham Young University CONTENTdm Server Repository',
#        u'lsr12': u'Brigham Young University - Harold B. Lee Library',
#        u'lsr13': u'Marcus Bach',
#        u'lsr15': u'Marcus Bach Collection',
#        u'recordid': u'digcoll_byu_12Bach2/2822',
#        u'rsrctype': u'text',
#        u'scope': u'mw',
#        u'sourceid': u'digcoll_byu_12',
#        u'subject': [u'Bach, Marcus, 1906- --Childhood and youth;', u'Books;'],
#        u'title': u'Who Stole my Utopia'},
#       u'sort': {u'author': u'Bach, M',
#        u'creationdate': u'1992',
#        u'title': u'Who Stole my Utopia'}},
#      u'xmlns': u'http://www.exlibrisgroup.com/xsd/primo/primo_nm_bib'},
#     u'RANK': u'0.79999995',
#     u'SEARCH_ENGINE': u'Local Search Engine',
#     u'SEARCH_ENGINE_TYPE': u'Local Search Engine',
#     u'_id': u'digcoll_byu_12Bach2/2822'},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/mwdl',
#     u'name': u'Mountain West Digital Library'},
#    u'score': 1.7960618,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/fcd9663d450b786d938cc53ae732fa13',
#      u'id': u'fcd9663d450b786d938cc53ae732fa13',
#      u'title': u'Mwdl'},
#     u'creator': u'Bach, Marcus, 1906-',
#     u'date': {u'begin': u'1992', u'displayDate': u'1992', u'end': u'1992'},
#     u'description': [u'Electronic reproduction', u'158 p. : ill. ; 22 cm.'],
#     u'identifier': u'http://contentdm.lib.byu.edu/u?/Bach2,2822',
#     u'isPartOf': u'Marcus Bach',
#     u'language': [{u'iso639_3': u'eng', u'name': u'English'}],
#     u'relation': u'Is part of: Marcus Bach Collection',
#     u'rights': u'Http://www.lib.byu.edu/generic_copyright.html; By permission of the Dr. Marcus and Lorena Bach Endowed Fund; Public',
#     u'stateLocatedIn': [{u'name': u'UT'}],
#     u'subject': [{u'name': u'Bach, Marcus, 1906--Childhood and youth'},
#      {u'name': u'Books'}],
#     u'title': u'Who Stole my Utopia',
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/ec99d5fafac135cd782ae38f10d521aa',
#    u'_id': u'ia--lesthtiquedeje00pirr',
#    u'_rev': u'1-ff239a0063d2648d4a26aee34e6dc2eb',
#    u'dataProvider': u'Wellesley College Library',
#    u'hasView': {u'@id': u'http://www.archive.org/download/lesthtiquedeje00pirr/lesthtiquedeje00pirr_bw.pdf',
#     u'format': u'application/pdf',
#     u'rights': u'NOT_IN_COPYRIGHT'},
#    u'id': u'ec99d5fafac135cd782ae38f10d521aa',
#    u'ingestDate': u'2013-04-12T15:13:04.856522',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://www.archive.org/details/lesthtiquedeje00pirr',
#    u'originalRecord': {u'_id': u'lesthtiquedeje00pirr',
#     u'files': {u'dc': u'lesthtiquedeje00pirr_dc.xml',
#      u'gif': u'lesthtiquedeje00pirr.gif',
#      u'marc': u'lesthtiquedeje00pirr_marc.xml',
#      u'meta': u'lesthtiquedeje00pirr_meta.xml',
#      u'pdf': u'lesthtiquedeje00pirr_bw.pdf',
#      u'shown_at': u'http://archive.org/details/lesthtiquedeje00pirr'},
#     u'metadata': {u'addeddate': u'2008-11-13 18:05:21',
#      u'call_number': u'b12626454',
#      u'camera': u'Canon 5D',
#      u'collection': [u'Wellesley_College_Library', u'blc', u'americana'],
#      u'contributor': u'Wellesley College Library',
#      u'creator': u'Pirro, Andr\xe9, 1869-1943',
#      u'curation': u'[curator]julie@archive.org[/curator][date]20081205014542[/date][state]approved[/state]',
#      u'date': u'1907',
#      u'description': [u'"Catalogue des uvres de Bach": p. [521]-523',
#       u'Bibliography: p. [525]-533'],
#      u'foldoutcount': u'0',
#      u'identifier': u'lesthtiquedeje00pirr',
#      u'identifier-access': u'http://www.archive.org/details/lesthtiquedeje00pirr',
#      u'identifier-ark': u'ark:/13960/t4rj4qm5x',
#      u'imagecount': u'560',
#      u'language': u'fre',
#      u'lcamid': None,
#      u'mediatype': u'texts',
#      u'missingpages': None,
#      u'operator': u'scanner-sarah-duncan@archive.org',
#      u'possible-copyright-status': u'NOT_IN_COPYRIGHT',
#      u'ppi': u'500',
#      u'publicdate': u'2008-11-13 18:05:25',
#      u'publisher': u'Paris : Fischbacher',
#      u'rcamid': None,
#      u'repub_state': u'4',
#      u'scandate': u'20081113223202',
#      u'scanfactors': u'4',
#      u'scanner': u'scribe2.boston.archive.org',
#      u'scanningcenter': u'boston',
#      u'sponsor': u'Wellesley College Library',
#      u'sponsordate': u'20081130',
#      u'subject': u'Bach, Johann Sebastian, 1685-1750',
#      u'title': u"L'esth\xe9tique de Jean-S\xe9bastien Bach",
#      u'updatedate': u'2008-11-13 18:05:08',
#      u'updater': u'francesca@archive.org',
#      u'uploader': u'francesca@archive.org'},
#     u'record': {u'controlfield': [{u'#text': u'2028632', u'tag': u'001'},
#       {u'#text': u'19860829154709.0', u'tag': u'005'},
#       {u'#text': u'760303s1907    fr ag    b    000 0 fre d', u'tag': u'008'}],
#      u'datafield': [{u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'BNG', u'code': u'a'},
#         {u'#text': u'BNG', u'code': u'c'},
#         {u'#text': u'm.c.', u'code': u'd'},
#         {u'#text': u'WEL', u'code': u'd'}],
#        u'tag': u'040'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'WELM', u'code': u'a'},
#        u'tag': u'049'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'ML410.B1', u'code': u'a'},
#         {u'#text': u'P6 1907', u'code': u'b'}],
#        u'tag': u'090'},
#       {u'ind1': u'1',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Pirro, Andr\xe9,', u'code': u'a'},
#         {u'#text': u'1869-1943.', u'code': u'd'}],
#        u'tag': u'100'},
#       {u'ind1': u'1',
#        u'ind2': u'2',
#        u'subfield': [{u'#text': u"L'esth\xe9tique de Jean-S\xe9bastien Bach /",
#          u'code': u'a'},
#         {u'#text': u'par Andr\xe9 Pirro.', u'code': u'c'}],
#        u'tag': u'245'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Paris :', u'code': u'a'},
#         {u'#text': u'Fischbacher,', u'code': u'b'},
#         {u'#text': u'1907.', u'code': u'c'}],
#        u'tag': u'260'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'538 p. :', u'code': u'a'},
#         {u'#text': u'ill., music ;', u'code': u'b'},
#         {u'#text': u'26 cm.', u'code': u'c'}],
#        u'tag': u'300'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'"Catalogue des uvres de Bach": p. [521]-523.',
#         u'code': u'a'},
#        u'tag': u'500'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'Bibliography: p. [525]-533.', u'code': u'a'},
#        u'tag': u'504'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach, Johann Sebastian,', u'code': u'a'},
#         {u'#text': u'1685-1750.', u'code': u'd'}],
#        u'tag': u'600'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'.b12626454', u'code': u'a'},
#        u'tag': u'907'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'music', u'code': u'a'},
#         {u'#text': u'1', u'code': u'b'},
#         {u'#text': u'880801', u'code': u'c'},
#         {u'#text': u'a', u'code': u'd'},
#         {u'#text': u'-', u'code': u'e'},
#         {u'#text': u'-', u'code': u'f'},
#         {u'#text': u'2', u'code': u'g'}],
#        u'tag': u'999'}],
#      u'leader': u'00660nam a2200205I  450 ',
#      u'xmlns': u'http://www.loc.gov/MARC21/slim'}},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/internet_archive',
#     u'name': u'Internet Archive'},
#    u'score': 1.7798026,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/190b7921c442008cb8e538f61cdab6cb',
#      u'id': u'190b7921c442008cb8e538f61cdab6cb',
#      u'title': u'Wellesley College Library'},
#     u'creator': u'Pirro, Andr\xe9, 1869-1943',
#     u'date': {u'begin': u'1907', u'displayDate': u'1907', u'end': u'1907'},
#     u'description': [u'Catalogue des uvres de Bach": p. [521]-523',
#      u'Bibliography: p. [525]-533'],
#     u'extent': u'26 cm.',
#     u'identifier': [u'lesthtiquedeje00pirr', u'b12626454'],
#     u'language': [{u'iso639_3': u'fre', u'name': u'French'}],
#     u'publisher': u'Paris : Fischbacher',
#     u'rights': u'NOT_IN_COPYRIGHT',
#     u'subject': [{u'name': u'Bach, Johann Sebastian, 1685-1750'}],
#     u'title': u"L'esth\xe9tique de Jean-S\xe9bastien Bach",
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/2d84c9b334d4a331bb65b0c77728bfb5',
#    u'_id': u'ia--friedemannbachei1858brac',
#    u'_rev': u'1-7a4a57d79ebdf58750ac8ad8765651b7',
#    u'dataProvider': u'University of Connecticut Libraries',
#    u'hasView': {u'@id': u'http://www.archive.org/download/friedemannbachei1858brac/friedemannbachei1858brac_bw.pdf',
#     u'format': u'application/pdf',
#     u'rights': u'NOT_IN_COPYRIGHT'},
#    u'id': u'2d84c9b334d4a331bb65b0c77728bfb5',
#    u'ingestDate': u'2013-04-12T18:53:54.793933',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://www.archive.org/details/friedemannbachei1858brac',
#    u'originalRecord': {u'_id': u'friedemannbachei1858brac',
#     u'files': {u'dc': u'friedemannbachei1858brac_dc.xml',
#      u'gif': u'friedemannbachei1858brac.gif',
#      u'marc': u'friedemannbachei1858brac_marc.xml',
#      u'meta': u'friedemannbachei1858brac_meta.xml',
#      u'pdf': u'friedemannbachei1858brac_bw.pdf',
#      u'shown_at': u'http://archive.org/details/friedemannbachei1858brac'},
#     u'metadata': {u'addeddate': u'2008-08-26 02:12:16',
#      u'call_number': u'04539982',
#      u'camera': u'Canon 5D',
#      u'collection': [u'uconn_libraries', u'blc', u'americana'],
#      u'contributor': u'University of Connecticut Libraries',
#      u'creator': u'Brachvogel, Albert Emil, 1824-1878',
#      u'curation': u'[curator]julie@archive.org[/curator][date]20080909210201[/date][state]approved[/state]',
#      u'date': u'1858',
#      u'foldoutcount': u'0',
#      u'identifier': u'friedemannbachei1858brac',
#      u'identifier-access': u'http://www.archive.org/details/friedemannbachei1858brac',
#      u'identifier-ark': u'ark:/13960/t9w09809d',
#      u'imagecount': u'382',
#      u'language': u'ger',
#      u'lcamid': None,
#      u'mediatype': u'texts',
#      u'missingpages': None,
#      u'operator': u'scanner-kelly-powers@archive.org',
#      u'possible-copyright-status': u'NOT_IN_COPYRIGHT',
#      u'ppi': u'500',
#      u'publicdate': u'2008-08-26 02:12:23',
#      u'publisher': u'Berlin : O. Janke',
#      u'rcamid': None,
#      u'repub_state': u'4',
#      u'scandate': u'20080826170144',
#      u'scanfactors': u'1',
#      u'scanner': u'scribe8.boston.archive.org',
#      u'scanningcenter': u'boston',
#      u'sponsor': u'University of Connecticut Libraries',
#      u'sponsordate': u'20080831',
#      u'subject': [u'Bach, Wilhelm Friedemann, 1710-1784', u'Bach family'],
#      u'title': u'Friedemann Bach : ein Roman',
#      u'updatedate': u'2008-08-26 02:12:14',
#      u'updater': u'tricia-gray@archive.org',
#      u'uploader': u'tricia-gray@archive.org',
#      u'volume': u'2'},
#     u'record': {u'controlfield': [{u'#text': u'221589', u'tag': u'001'},
#       {u'#text': u'19990630230741.0', u'tag': u'005'},
#       {u'#text': u'790111s1858    gw            000 1 ger d', u'tag': u'008'}],
#      u'datafield': [{u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'(OCoLC)04539982', u'code': u'a'},
#        u'tag': u'035'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'AAY3200ST', u'code': u'9'},
#        u'tag': u'035'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'UCW', u'code': u'a'},
#         {u'#text': u'UCW', u'code': u'c'}],
#        u'tag': u'040'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'UCWW', u'code': u'a'},
#        u'tag': u'049'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'PT1824.B4', u'code': u'a'},
#         {u'#text': u'F7', u'code': u'b'},
#         {u'#text': u'UCWW', u'code': u'm'}],
#        u'tag': u'090'},
#       {u'ind1': u'1',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Brachvogel, Albert Emil,', u'code': u'a'},
#         {u'#text': u'1824-1878.', u'code': u'd'}],
#        u'tag': u'100'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Friedemann Bach :', u'code': u'a'},
#         {u'#text': u'ein Roman /', u'code': u'b'},
#         {u'#text': u'von A. E. Brachvogel.', u'code': u'c'}],
#        u'tag': u'245'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'Berlin :', u'code': u'a'},
#         {u'#text': u'O. Janke,', u'code': u'b'},
#         {u'#text': u'1858.', u'code': u'c'}],
#        u'tag': u'260'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': [{u'#text': u'2 v. ;', u'code': u'a'},
#         {u'#text': u'18 cm.', u'code': u'c'}],
#        u'tag': u'300'},
#       {u'ind1': u'1',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach, Wilhelm Friedemann,', u'code': u'a'},
#         {u'#text': u'1710-1784', u'code': u'd'},
#         {u'#text': u'In literature.', u'code': u'x'}],
#        u'tag': u'600'},
#       {u'ind1': u'3',
#        u'ind2': u'0',
#        u'subfield': [{u'#text': u'Bach family', u'code': u'a'},
#         {u'#text': u'In literature.', u'code': u'x'}],
#        u'tag': u'600'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'IN  11 JAN 79', u'code': u'a'},
#        u'tag': u'940'},
#       {u'ind1': u' ',
#        u'ind2': u' ',
#        u'subfield': {u'#text': u'HLD pd', u'code': u'a'},
#        u'tag': u'948'}],
#      u'leader': u'00630nam a2200217 i 4500',
#      u'xmlns': u'http://www.loc.gov/MARC21/slim'}},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/internet_archive',
#     u'name': u'Internet Archive'},
#    u'score': 1.764731,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/190b7921c442008cb8e538f61cdab6cb',
#      u'id': u'190b7921c442008cb8e538f61cdab6cb',
#      u'title': u'University of Connecticut Libraries'},
#     u'creator': u'Brachvogel, Albert Emil, 1824-1878',
#     u'date': {u'begin': u'1858', u'displayDate': u'1858', u'end': u'1858'},
#     u'extent': u'18 cm.',
#     u'identifier': [u'friedemannbachei1858brac', u'04539982'],
#     u'language': [{u'iso639_3': u'deu', u'name': u'German'}],
#     u'publisher': u'Berlin : O. Janke',
#     u'rights': u'NOT_IN_COPYRIGHT',
#     u'subject': [{u'name': u'Bach, Wilhelm Friedemann, 1710-1784'},
#      {u'name': u'Bach family'}],
#     u'title': u'Friedemann Bach : ein Roman, 2',
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/18c3f13ecc1a96091e581535f4047cf9',
#    u'_id': u'digital-commonwealth--http://digitalcommonwealth.org/items/show/62889',
#    u'_rev': u'1-0b4ff9800d30941393ce56c1806286af',
#    u'dataProvider': u'Digital Commonwealth',
#    u'id': u'18c3f13ecc1a96091e581535f4047cf9',
#    u'ingestDate': u'2013-04-12T08:11:05.408792',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://openvault.wgbh.org/catalog/vietnam-hts-r4-christmas-bombing-church-bach-m ai  ',
#    u'originalRecord': {u'datestamp': u'2013-02-24T19:26:37Z',
#     u'handle': [u'http://openvault.wgbh.org/catalog/vietnam-hts-r4-christmas-bombing-church-bach-m ai  ',
#      u'http://digitalcommonwealth.org/items/show/62889'],
#     u'id': u'oai:digitalcommonwealth.org:62889',
#     u'label': u'Christmas Bombing, Church, Bach Mai  ',
#     u'setSpec': u'215',
#     u'title': u'Christmas Bombing, Church, Bach Mai  '},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/digital-commonwealth',
#     u'name': u'Digital Commonwealth'},
#    u'score': 1.6933432,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/285ca7b8845da5e6316e6558fac491b4',
#      u'id': u'285ca7b8845da5e6316e6558fac491b4',
#      u'title': u'Buckland Collection'},
#     u'title': u'Christmas Bombing, Church, Bach Mai'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:dateRangeEnd', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/ce8c4e81295d3d28fd9921d7d84ae205',
#    u'_id': u'bhl--http://www.biodiversitylibrary.org/item/60813',
#    u'_rev': u'1-9fcedf7a4eb260034f6ec5f53cde6f6f',
#    u'dataProvider': u'Webster Family Library of Veterinary Medicine (archive.org)',
#    u'id': u'ce8c4e81295d3d28fd9921d7d84ae205',
#    u'ingestDate': u'2013-04-11T23:39:13.857964',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://www.biodiversitylibrary.org/item/60813',
#    u'originalRecord': {u'contributor': u'Webster Family Library of Veterinary Medicine (archive.org)',
#     u'creator': u'Bach, F. W.      ',
#     u'datestamp': u'2012-05-16T12:30:57Z',
#     u'description': u'',
#     u'handle': u'http://www.biodiversitylibrary.org/item/60813',
#     u'id': u'oai:biodiversitylibrary.org:item/60813',
#     u'label': u'How to judge a horse : a concise treatise as to its qualities & soundness / by F.W. Bach.',
#     u'language': u'English',
#     u'publisher': u'New York :Jenkins,1893.',
#     u'rights': u'NOT_IN_COPYRIGHT',
#     u'setSpec': u'item',
#     u'subject': u'Horses',
#     u'title': u'How to judge a horse : a concise treatise as to its qualities & soundness / by F.W. Bach.',
#     u'type': [u'text', u'Book']},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/bhl',
#     u'name': u'Biodiversity Heritage Library'},
#    u'score': 1.6767429,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/bhl--WFLoVM(',
#      u'id': u'24087df2c58f149a8167a9589cffd830',
#      u'name': u'Webster Family Library of Veterinary Medicine (archive.org)',
#      u'title': u'Volumes'},
#     u'creator': u'Bach, F. W',
#     u'description': u'',
#     u'format': u'Book',
#     u'language': [{u'iso639_3': u'eng', u'name': u'English'}],
#     u'publisher': u'New York :Jenkins,1893',
#     u'rights': u'NOT_IN_COPYRIGHT',
#     u'subject': [{u'name': u'Horses'}],
#     u'title': u'How to judge a horse : a concise treatise as to its qualities & soundness / by F.W. Bach',
#     u'type': u'text'}},
#   435),
#  ({u'@context': {u'@vocab': u'http://purl.org/dc/terms/',
#     u'LCSH': u'http://id.loc.gov/authorities/subjects',
#     u'aggregatedDigitalResource': u'dpla:aggregatedDigitalResource',
#     u'begin': {u'@id': u'dpla:dateRangeStart', u'@type': u'xsd:date'},
#     u'collection': u'dpla:aggregation',
#     u'coordinates': u'dpla:coordinates',
#     u'dataProvider': u'edm:dataProvider',
#     u'dpla': u'http://dp.la/terms/',
#     u'edm': u'http://www.europeana.eu/schemas/edm/',
#     u'end': {u'@id': u'dpla:end', u'@type': u'xsd:date'},
#     u'hasView': u'edm:hasView',
#     u'isShownAt': u'edm:isShownAt',
#     u'name': u'xsd:string',
#     u'object': u'edm:object',
#     u'originalRecord': u'dpla:originalRecord',
#     u'provider': u'edm:provider',
#     u'sourceResource': u'edm:sourceResource',
#     u'state': u'dpla:state',
#     u'stateLocatedIn': u'dpla:stateLocatedIn'},
#    u'@id': u'http://dp.la/api/items/546043d029317af46d473372dd8f7bb9',
#    u'_id': u'mwdl--digcoll_byu_12Bach2/8119',
#    u'_rev': u'1-6d949276219a3c22a2c84cd2656b4c56',
#    u'dataProvider': u'Brigham Young University - Harold B. Lee Library',
#    u'id': u'546043d029317af46d473372dd8f7bb9',
#    u'ingestDate': u'2013-04-12T21:33:58.273338',
#    u'ingestType': u'item',
#    u'isShownAt': u'http://thoth.library.utah.edu:1701/primo_library/libweb/action/dlDisplay.do?vid=MWDL&afterPDS=true&docId=digcoll_byu_12Bach2/8119',
#    u'object': u'http://contentdm.lib.byu.edu/utils/getthumbnail/collection/Bach2/id/8119',
#    u'originalRecord': {u'GETIT': {u'GetIt1': u'http://archives.state.ut.us/cgi-bin/index-oai.cgi?KEYPATH=IDX208420190387',
#      u'GetIt2': u'http://sfx7.exlibrisgroup.com/uutah?ctx_ver=Z39.88-2004&ctx_enc=info:ofi/enc:UTF-8&ctx_tim=2013-04-12T19%3A31%3A44IST&url_ver=Z39.88-2004&url_ctx_fmt=infofi/fmt:kev:mtx:ctx&rfr_id=info:sid/primo.exlibrisgroup.com:primo3-Journal-digcoll_usa_24&rft_val_fmt=info:ofi/fmt:kev:mtx:&rft.genre=&rft.atitle=&rft.jtitle=&rft.btitle=&rft.aulast=&rft.auinit=&rft.auinit1=&rft.auinitm=&rft.ausuffix=&rft.au=&rft.aucorp=&rft.volume=&rft.issue=&rft.part=&rft.quarter=&rft.ssn=&rft.spage=&rft.epage=&rft.pages=&rft.artnum=&rft.issn=&rft.eissn=&rft.isbn=&rft.sici=&rft.coden=&rft_id=info:doi/&rft.object_id=&rft.eisbn=&rft_dat=<digcoll_usa_24>190387</digcoll_usa_24>&rft_id=info:oai/',
#      u'deliveryCategory': u'Online Resource'},
#     u'ID': u'1898799',
#     u'LINKS': {u'linktorsrc': u'http://contentdm.lib.byu.edu/u?/Bach2,8119',
#      u'thumbnail': u'http://contentdm.lib.byu.edu/utils/getthumbnail/collection/Bach2/id/8119'},
#     u'NO': u'225725',
#     u'PrimoNMBib': {u'record': {u'addata': {u'date': u'1952',
#        u'pub': [u'Indianapolis : Bobbs-Merrill Co.',
#         u'Brigham Young University']},
#       u'control': {u'addsrcrecordid': u'byu-12-102-1077',
#        u'originalsourceid': u'8119',
#        u'recordid': u'digcoll_byu_12Bach2/8119',
#        u'sourcedbandrecordid': u'Bach2',
#        u'sourceformat': u'Digital Entity',
#        u'sourceid': u'digcoll_byu_12',
#        u'sourcerecordid': u'Bach2/8119',
#        u'sourcesystem': u'Other'},
#       u'delivery': {u'delcategory': u'Online Resource',
#        u'institution': u'MWDL'},
#       u'display': {u'creationdate': u'1952',
#        u'creator': u'Bach, Marcus, 1906-',
#        u'description': [u'Electronic reproduction;',
#         u'254 p. : ill. ; 23 cm.'],
#        u'format': u'text/pdf',
#        u'identifier': u'http://contentdm.lib.byu.edu/u?/Bach2,8119',
#        u'language': u'eng;eng;eng',
#        u'lds01': u'Brigham Young University, Harold B. Lee Library',
#        u'lds02': u'Brigham Young University CONTENTdm Server Repository',
#        u'lds03': u'Brigham Young University - Harold B. Lee Library',
#        u'lds04': u'Marcus Bach',
#        u'lds12': u'Brigham Young University',
#        u'lds17': u'text',
#        u'lds18': u'text',
#        u'publisher': u'Indianapolis : Bobbs-Merrill Co.; Brigham Young University',
#        u'relation': u'Is part of: Marcus Bach Collection',
#        u'rights': u'http://www.lib.byu.edu/generic_copyright.html; By permission of the Dr. Marcus and Lorena Bach Endowed Fund; Public',
#        u'subject': u'Voodooism; Folklore--Haiti; Reser, Stanley;; Books;',
#        u'title': u'Strange Altars',
#        u'type': u'Text'},
#       u'facets': {u'collection': u'Digital Collections',
#        u'creationdate': [u'1952', u'2006-01'],
#        u'creatorcontrib': u'Bach, Marcus, 1906-',
#        u'format': u'text/pdf',
#        u'frbrgroupid': u'110901745',
#        u'frbrtype': u'6',
#        u'genre': u'unknown',
#        u'language': [u'eng', u'eng', u'eng'],
#        u'lfc01': u'Marcus Bach',
#        u'lfc02': u'Brigham Young University - Harold B. Lee Library',
#        u'lfc03': u'Brigham Young University, Harold B. Lee Library',
#        u'lfc04': u'Brigham Young University CONTENTdm Server Repository',
#        u'prefilter': u'text',
#        u'rsrctype': u'text',
#        u'topic': [u'Voodooism',
#         u'Folklore--Haiti',
#         u'Reser, Stanley',
#         u'Books'],
#        u'toplevel': u'online_resources'},
#       u'links': {u'linktorsrc': u'$$Tdigcoll_byu_12_linktores$$DOpen resource in a new window',
#        u'thumbnail': u'$$Tdigcoll_byu_12_linktothumb$$DSee Thumbnail'},
#       u'ranking': {u'booster1': u'1', u'booster2': u'1'},
#       u'search': {u'addsrcrecordid': u'byu-12-102-1077',
#        u'addtitle': u'Is part of: Marcus Bach Collection',
#        u'creationdate': [u'1952', u'2006-01'],
#        u'creatorcontrib': u'Bach, Marcus, 1906-',
#        u'description': [u'Electronic reproduction;',
#         u'254 p. : ill. ; 23 cm.'],
#        u'lsr01': u'byu',
#        u'lsr02': u'12',
#        u'lsr03': u'102',
#        u'lsr04': u'1077',
#        u'lsr09': u'Brigham Young University, Harold B. Lee Library',
#        u'lsr10': u'Brigham Young University CONTENTdm Server Repository',
#        u'lsr12': u'Brigham Young University - Harold B. Lee Library',
#        u'lsr13': u'Marcus Bach',
#        u'lsr15': u'Marcus Bach Collection',
#        u'recordid': u'digcoll_byu_12Bach2/8119',
#        u'rsrctype': u'text',
#        u'scope': u'mw',
#        u'sourceid': u'digcoll_byu_12',
#        u'subject': [u'Voodooism; Folklore--Haiti; Reser, Stanley;', u'Books;'],
#        u'title': u'Strange Altars'},
#       u'sort': {u'author': u'Bach, M',
#        u'creationdate': u'1952',
#        u'title': u'Strange Altars'}},
#      u'xmlns': u'http://www.exlibrisgroup.com/xsd/primo/primo_nm_bib'},
#     u'RANK': u'0.79999995',
#     u'SEARCH_ENGINE': u'Local Search Engine',
#     u'SEARCH_ENGINE_TYPE': u'Local Search Engine',
#     u'_id': u'digcoll_byu_12Bach2/8119'},
#    u'provider': {u'@id': u'http://dp.la/api/contributor/mwdl',
#     u'name': u'Mountain West Digital Library'},
#    u'score': 1.6646321,
#    u'sourceResource': {u'collection': {u'@id': u'http://dp.la/api/collections/fcd9663d450b786d938cc53ae732fa13',
#      u'id': u'fcd9663d450b786d938cc53ae732fa13',
#      u'title': u'Mwdl'},
#     u'creator': u'Bach, Marcus, 1906-',
#     u'date': {u'begin': u'1952', u'displayDate': u'1952', u'end': u'1952'},
#     u'description': [u'Electronic reproduction', u'254 p. : ill. ; 23 cm.'],
#     u'identifier': u'http://contentdm.lib.byu.edu/u?/Bach2,8119',
#     u'isPartOf': u'Marcus Bach',
#     u'language': [{u'iso639_3': u'eng', u'name': u'English'}],
#     u'relation': u'Is part of: Marcus Bach Collection',
#     u'rights': u'Http://www.lib.byu.edu/generic_copyright.html; By permission of the Dr. Marcus and Lorena Bach Endowed Fund; Public',
#     u'stateLocatedIn': [{u'name': u'UT'}],
#     u'subject': [{u'name': u'Voodooism'},
#      {u'name': u'Folklore--Haiti'},
#      {u'name': u'Reser, Stanley'},
#      {u'name': u'Books'}],
#     u'title': u'Strange Altars',
#     u'type': u'text'}},
#   435)]
